# %%
# %matplotlib inline

# %%
path = '../data/redux/'
# path = '../data/redux/sample/'

# %%
from __future__ import division,print_function
import os
import json
from glob import glob
import numpy as np
np.set_printoptions(precision=4, linewidth=100)
import matplotlib.pyplot as plt

# %%
import utils; reload(utils)
from utils import plots
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)
# Using Theano backend.

# %%
batch_size = 64
# batch_size = 4

# %%
import vgg16; reload(vgg16)
from vgg16 import Vgg16

# %%
vgg = Vgg16()
batches = vgg.get_batches(path+'train',batch_size=batch_size)
val_batches = vgg.get_batches(path+'valid',batch_size=batch_size)
vgg.finetune(batches)
vgg.fit(batches,val_batches,nb_epoch=1)
# Out:
# Found 23000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Epoch 1/1
# 23000/23000 [==============================] - 658s - loss: 0.1195 - acc: 0.9686 - val_loss: 0.0853 - val_acc: 0.9795

# %%
vgg.model.save_weights(path+'results/ft1.h5')

# %% [markdown]
# #### Predictions

# %%
test_batches, test_preds =vgg.test(path+'test/')
# Out:
# Found 12500 images belonging to 1 classes.

# %%
filenames = test_batches.filenames

# %%
utils.save_array(path+'results/test_preds.dat',test_preds)
utils.save_array(path+'results/filenames.dat',filenames)

# %%
preds = utils.load_array(path+'results/test_preds.dat')
filenames = utils.load_array(path+'results/filenames.dat')

# %%
filenames[:5]
# Out:
# array(['unknown/9292.jpg', 'unknown/12026.jpg', 'unknown/9688.jpg', 'unknown/4392.jpg',
#        'unknown/779.jpg'],
#       dtype='|S17')

# %%
preds[:5]
# Out:
# array([[  1.0000e+00,   1.7129e-11],
#        [  9.5123e-01,   4.8765e-02],
#        [  1.0000e+00,   1.1433e-07],
#        [  1.0000e+00,   1.2510e-13],
#        [  2.0968e-08,   1.0000e+00]], dtype=float32)

# %%
is_dog = preds[:,1]
is_dog[:5]
# Out:
# array([  1.7129e-11,   4.8765e-02,   1.1433e-07,   1.2510e-13,   1.0000e+00], dtype=float32)

# %%
ids = [int(f[8:f.find('.')]) for f in filenames]
ids[:5]
# Out:
# [9292, 12026, 9688, 4392, 779]

# %%
subm = np.stack([ids,is_dog],axis=1)
subm[:5]
# Out:
# array([[  9.2920e+03,   1.7129e-11],
#        [  1.2026e+04,   4.8765e-02],
#        [  9.6880e+03,   1.1433e-07],
#        [  4.3920e+03,   1.2510e-13],
#        [  7.7900e+02,   1.0000e+00]])

# %%
np.savetxt(path+'results/subm97.csv',subm,fmt='%d,%.5f',header='id,label',comments='')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-30-a92334457622> in <module>()
# ----> 1 np.savetxt('redux/data/results/subm97.csv',subm,fmt='%d,%.5f',header='id,label',comments='')
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments)
#    1096                 fh = open(fname, 'wb')
#    1097             else:
# -> 1098                 fh = open(fname, 'w')
#    1099     elif hasattr(fname, 'write'):
#    1100         fh = fname
#
# IOError: [Errno 2] No such file or directory: 'redux/data/results/subm97.csv'

# %%
from IPython.display import FileLink
FileLink(path+'results/subm97.csv')

# %% [markdown]
# #### Validate Predictions

# %%
import vgg16; reload(vgg16)
from vgg16 import Vgg16

import utils; reload(utils)
from utils import *
# Out:
# Using Theano backend.
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %%
path = '../data/redux/'
# path = '../data/redux/sample/'

# %%
valid_path = path+'valid/'

# %%
# batch_size = 4
batch_size = 64

# %%
vgg = Vgg16()

# %%
vgg.model.load_weights(path+'results/ft1.h5')

# %%
val_batches, preds = vgg.test(path+'valid',batch_size)
# Out:
# Found 2000 images belonging to 2 classes.

# %%
preds[:5]
# Out:
# array([[  1.0000e+00,   8.3961e-09],
#        [  1.0000e+00,   4.1656e-11],
#        [  1.0000e+00,   3.5989e-09],
#        [  1.0000e+00,   3.4920e-13],
#        [  1.0000e+00,   2.2145e-06]], dtype=float32)

# %%
filenames = val_batches.filenames
expected_labels = val_batches.classes

# %%
our_preds = preds[:,1]
our_labels = np.round(our_preds)

# %%
n_view = 4

# %%
from numpy.random import permutation

# %%
from keras.preprocessing import image
#Helper function to plot images by index in the validation set 
def plots_idx(idx, titles=None):
    plots([image.load_img(valid_path + filenames[i]) for i in idx], titles=titles)

# %%
#1. A few correct labels at random
correct = np.where(expected_labels==our_labels)[0]
print "Found {} correct labels".format(len(correct))
idx = permutation(correct)[:n_view]
plots_idx(idx,our_preds[idx])
plt.show()
plt.close()
# Out:
# Found 1959 correct labels

# %%
#1. A few incorrect labels at random
incorrect = np.where(expected_labels!=our_labels)[0]
print "Found {} incorrect labels".format(len(incorrect))
idx = permutation(incorrect)[:n_view]
plots_idx(idx,our_preds[idx])
plt.show()
plt.close()
# Out:
# Found 41 incorrect labels

# %%
# Most correct dogs
correct_dogs = np.where((expected_labels==our_labels) & (our_labels==1))[0]
print "Found {} Most confident dogs and are actually dogs".format(len(correct_dogs))
idx = permutation(correct_dogs)[:n_view]
plots_idx(idx,our_preds[idx])
plt.show()
plt.close()
# Out:
# Found 969 Most confident dogs and are actually dogs

# %%
# Most correct cats
correct_cats = np.where((expected_labels==our_labels) & (our_labels==0))[0]
print "Found {} Most confident cats and are actually cats".format(len(correct_cats))
idx = permutation(correct_cats)[:n_view]
plots_idx(idx,our_preds[idx])
plt.show()
plt.close()
# Out:
# Found 990 Most confident cats and are actually cats

# %%
# Most incorrect dogs
incorrect_dogs = np.where((expected_labels!=our_labels) & (our_labels==1))[0]
print "Found {} Most confident dogs but, are not actually dogs".format(len(incorrect_dogs))
idx = permutation(incorrect_dogs)[:n_view]
plots_idx(idx,our_preds[idx])
plt.show()
plt.close()
# Out:
# Found 10 Most confident dogs but, are not actually dogs

# %%
# Most incorrect cats
incorrect_cats = np.where((expected_labels!=our_labels) & (our_labels==0))[0]
print "Found {} Most confident cats but, are not actually cats".format(len(incorrect_cats))
idx = permutation(incorrect_cats)[:n_view]
plots_idx(idx,our_preds[idx])
plt.show()
plt.close()
# Out:
# Found 31 Most confident cats but, are not actually cats

# %%
# Most Uncertain
uncertain_labels = np.argsort(np.abs((our_preds-0.5)))
# print "Found {} Most confident cats but, are not actually cats".format(len(uncertain_labels))
# idx = permutation(uncertain_labels)[:n_view]
plots_idx(uncertain_labels[:n_view], our_preds[uncertain_labels])
plt.show()
plt.close()
