# %%
# %matplotlib inline
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# path = 'data/dogscats/'
path = 'data/dogscats/sample/'

# %%
from __future__ import division,print_function
import os
import json
from glob import glob
import numpy as np
np.set_printoptions(precision=4, linewidth=100)
import matplotlib.pyplot as plt

# %%
import utils; reload(utils)
from utils import plots

# %%
# batch_size = 64
batch_size = 4

# %%
import vgg16; reload(vgg16)
from vgg16 import Vgg16

# %%
vgg = Vgg16()
batches = vgg.get_batches(path+'train',batch_size=batch_size)
val_batches = vgg.get_batches(path+'valid',batch_size=batch_size)
vgg.finetune(batches)
vgg.fit(batches,val_batches,nb_epoch=1)
# Out:
# Found 16 images belonging to 2 classes.
# Found 8 images belonging to 2 classes.
# Epoch 1/1
# 16/16 [==============================] - 6s - loss: 0.2663 - acc: 0.9375 - val_loss: 0.6689 - val_acc: 0.6250

# %% [markdown]
# #### Some Explainations

# %%
vgg = Vgg16()

# %%
batches = vgg.get_batches(path+'train', batch_size=4)
# Out:
# Found 16 images belonging to 2 classes.

# %%
imgs,labels = next(batches)

# %%
plots(imgs, titles=labels)

# %%
vgg.predict(imgs, True)
# Out:
# (array([ 0.1044,  0.2802,  0.9111,  0.0493], dtype=float32),
#  array([333, 285, 244, 370]),
#  [u'hamster', u'Egyptian_cat', u'Tibetan_mastiff', u'guenon'])

# %%
vgg.classes[:4]
# Out:
# [u'tench', u'goldfish', u'great_white_shark', u'tiger_shark']
